# %% [markdown]
# #INTRODUCTION
#
#
# ---
#
#
#
# The world's energy consumption is a major contributor to climate change, and reducing energy consumption is a critical step in mitigating its negative impacts. One way to achieve this goal is through the use of optimization algorithms, which can identify the most efficient solutions for a given problem. In this report, we will explore the potential for using the crow search algorithm to minimize energy consumption, as represented in a dataset containing information about energy consumption and production for different countries over time.
#
# The crow search algorithm is a population-based optimization technique that is inspired by the behavior of crows searching for food. It has been applied to a wide range of optimization problems, including those related to energy consumption. The dataset used in this report includes information on various energy sources, including coal, gas, oil, and biofuels, as well as data on electricity generation and consumption, carbon intensity, and per capita energy consumption. We will describe the basic principles of the crow search algorithm and how it can be applied to minimize energy consumption using this dataset. We will then present the results of our analysis, including any insights we can draw from the data.
#
#
# Overall, this report aims to provide a comprehensive overview of the potential for using the crow search algorithm to minimize energy consumption, and to identify any potential challenges or limitations in its application using the dataset described above.

# %% [markdown]
# # DESCRIBING THE DATASET
#
# ---
#
#
#
# The dataset includes data on various energy sources and their consumption and production over time, including coal, gas, oil, and biofuels. It includes data on the percentage and total annual change in these energy sources, as well as data on their share of primary energy consumption and electricity generation. The dataset also includes data on carbon intensity, per capita energy consumption and production, and electricity generation from various sources, including fossil fuels, renewables, and specific renewable sources such as hydroelectric power and solar energy.
#
# In addition to data on energy sources, the dataset also includes data on energy consumption and production in relation to GDP and population size, including per capita energy consumption and energy consumption per unit of GDP. This can be useful for understanding how energy consumption and production vary across countries and how these factors relate to economic and demographic factors.
#
# Overall, the dataset provides a wide range of information about energy consumption and production for different countries over time, which can be useful for understanding trends and patterns in these metrics and for identifying potential opportunities for minimizing energy consumption through the use of optimization algorithms such as the crow search algorithm.

# %% [markdown]
# # COLUMNS
#
# ---
#
#
#
# iso_code: ISO 3166-1 alpha-3 three-letter country codes
# country: Geographic location
# year: Year of observation
# The remaining columns contain data on various energy sources and related metrics, including:
#
# coalprodchange_pct: Annual percentage change in coal production
# coalprodchange_twh: Annual change in coal production, measured in terawatt-hours
# gasprodchange_pct: Annual percentage change in gas production
# gasprodchange_twh: Annual change in gas production, measured in terawatt-hours
# oilprodchange_pct: Annual percentage change in oil production
# oilprodchange_twh: Annual change in oil production, measured in terawatt-hours
# energyconschange_pct: Annual percentage change in primary energy consumption
# energyconschange_twh: Annual change in primary energy consumption, measured in terawatt-hours
# The dataset also includes data on biofuels, including:
#
# biofuelshareelec: Share of electricity consumption that comes from biofuels
# biofuelconschange_pct: Annual percentage change in biofuel consumption
# biofuelshareenergy: Share of primary energy consumption that comes from biofuels
# biofuelconschange_twh: Annual change in biofuel consumption, measured in terawatt-hours
# biofuel_consumption: Primary energy consumption from biofuels, measured in terawatt-hours
# biofuelelecper_capita: Per capita electricity consumption from biofuels, measured in kilowatt-hours
# biofuelconsper_capita: Per capita primary energy consumption from biofuels, measured in kilowatt-hours
# There is also data on coal consumption and production, including:
#
# carbonintensityelec: Carbon intensity of electricity production, measured in grams of carbon dioxide emitted per kilowatt-hour
# coalshareelec: Share of electricity consumption that comes from coal
# coalconschange_pct: Annual percentage change in coal consumption
# coalshareenergy: Share of primary energy consumption that comes from coal
# coalconschange_twh: Annual change in coal consumption, measured in terawatt-hours
# coal_consumption: Primary energy consumption from coal, measured in terawatt-hours
# coalelecper_capita: Per capita electricity consumption from coal, measured in kilowatt-hours
# coalconsper_capita: Per capita primary energy consumption from coal, measured in kilowatt-hours
# coal_production: Coal production, measured in terawatt-hours
# coalprodper_capita: Per capita coal production, measured in kilowatt-hours
# There is also data on electricity generation and consumption, including:
#
# electricity_generation: Electricity generation, measured in terawatt-hours
# biofuel_electricity: Electricity generation from biofuels, measured in terawatt-hours
# coal_electricity: Electricity generation from coal, measured in terawatt-hours
# fossil_electricity: Electricity generation from fossil fuels, measured in terawatt-hours. This is the sum of electricity generation from coal, oil and gas.
# gas_electricity: Electricity generation from gas, measured in terawatt-hours
# hydro_electricity: Electricity generation from hydropower, measured in teraw

# %% [markdown]
# #Download data

# %%
# !wget https://github.com/Ghassanee/Crow_search/raw/main/World%20Energy%20Consumption.csv
# Out:
# --2022-12-20 10:43:01--  https://github.com/Ghassanee/Crow_search/raw/main/World%20Energy%20Consumption.csv
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Ghassanee/Crow_search/main/World%20Energy%20Consumption.csv [following]
# --2022-12-20 10:43:01--  https://raw.githubusercontent.com/Ghassanee/Crow_search/main/World%20Energy%20Consumption.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5325796 (5.1M) [text/plain]
# Saving to: ‘World Energy Consumption.csv’
#
# World Energy Consum 100%[===================>]   5.08M  --.-KB/s    in 0.03s
#
# ...

# %% [markdown]
# #Download packages and Imports

# %%
import pandas as pd 
import seaborn  
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# %% [markdown]
# #Load data

# %%
energydata = pd.read_csv('/content/World Energy Consumption.csv')
energydata.head()
# Out:
#   iso_code      country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0      AFG  Afghanistan  1900                   NaN                   NaN
# 1      AFG  Afghanistan  1901                   NaN                   0.0
# 2      AFG  Afghanistan  1902                   NaN                   0.0
# 3      AFG  Afghanistan  1903                   NaN                   0.0
# 4      AFG  Afghanistan  1904                   NaN                   0.0
#
#    gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    oil_prod_change_twh  energy_cons_change_pct  ...  solar_elec_per_capita  \
# ...

# %%
energydata.tail()
# Out:
#       iso_code   country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 17427      ZWE  Zimbabwe  2015               -25.013               -10.847
# 17428      ZWE  Zimbabwe  2016               -37.694               -12.257
# 17429      ZWE  Zimbabwe  2017                 8.375                 1.697
# 17430      ZWE  Zimbabwe  2018                22.555                 4.952
# 17431      ZWE  Zimbabwe  2019               -35.015                -9.422
#
#        gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# 17427                  NaN                  NaN                  NaN
# 17428                  NaN                  NaN                  NaN
# 17429                  NaN                  NaN                  NaN
# 17430                  NaN                  NaN                  NaN
# 17431                  NaN                  NaN                  NaN
#
#        oil_prod_change_twh  energy_cons_change_pct  ...  \
# ...

# %% [markdown]
# #Filter data

# %%
#Filter on needed columns
energydata=energydata[['country','year','coal_production','electricity_generation','energy_cons_change_pct','energy_cons_change_twh','biofuel_electricity','coal_electricity','fossil_electricity','gas_electricity','hydro_electricity','nuclear_electricity','oil_electricity','renewables_electricity','oil_production','fossil_share_energy','fossil_cons_change_twh','fossil_fuel_consumption','fossil_cons_change_pct','population','gdp','gas_production','solar_electricity','wind_electricity','energy_per_gdp','energy_per_capita']]
#Filter on year >=1985
energydata=energydata[energydata['year']>=1990]
#Filter on countries 
Countries=['Egypt','Saudi Arabia','United Kingdom','France','Germany','United States','Japan','India']
#filter columns
energydata=energydata.loc[energydata['country'].isin(Countries)]
energydata.tail(3)
# Out:
#              country  year  coal_production  electricity_generation  \
# 16367  United States  2018         4277.455                4203.937
# 16368  United States  2019         3972.480                4161.834
# 16369  United States  2020              NaN                4049.847
#
#        energy_cons_change_pct  energy_cons_change_twh  biofuel_electricity  \
# 16367                   3.544                 908.999               61.901
# 16368                  -0.998                -265.032               57.507
# 16369                     NaN                     NaN               56.055
#
#        coal_electricity  fossil_electricity  gas_electricity  ...  \
# 16367          1145.962            2666.350         1482.189  ...
# 16368           964.957            2595.032         1598.303  ...
# 16369           773.806            2431.990         1629.237  ...
#
#        fossil_cons_change_twh  fossil_fuel_consumption  \
# 16367                 864.750                22196.473
# ...

# %%
unique_values = pd.unique(energydata['year'])
unique_values
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %% [markdown]
# #Data visualisation and cleaning

# %%
#boxplot of solar_electricity
seaborn.boxplot(data=energydata, x="solar_electricity")

# %%
#boxplot of energy_per_gdp
seaborn.boxplot(data=energydata, x="energy_per_gdp")

# %%
#boxplot of gdp
seaborn.boxplot(data=energydata , x='gdp')

# %%
energydata.describe()
# Out:
#               year  coal_production  electricity_generation  \
# count   246.000000       150.000000              246.000000
# mean   2004.878049      1833.510127              930.948492
# std       8.895388      2253.094120             1164.309796
# min    1990.000000         4.860000               41.952000
# 25%    1997.000000       123.409500              322.931750
# 50%    2005.000000       670.783000              548.631000
# 75%    2012.750000      2958.334250              991.504500
# max    2020.000000      6694.609000             4203.937000
#
#        energy_cons_change_pct  energy_cons_change_twh  biofuel_electricity  \
# count              240.000000              240.000000           166.000000
# mean                 1.635854               56.244654            18.863819
# std                  3.310228              214.427812            20.291209
# min                 -8.822000            -1299.083000             0.000000
# ...

# %%
energydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 246 entries, 4951 to 16369
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   country                  246 non-null    object
#  1   year                     246 non-null    int64
#  2   coal_production          150 non-null    float64
#  3   electricity_generation   246 non-null    float64
#  4   energy_cons_change_pct   240 non-null    float64
#  5   energy_cons_change_twh   240 non-null    float64
#  6   biofuel_electricity      166 non-null    float64
#  7   coal_electricity         236 non-null    float64
#  8   fossil_electricity       236 non-null    float64
#  9   gas_electricity          236 non-null    float64
#  10  hydro_electricity        246 non-null    float64
#  11  nuclear_electricity      246 non-null    float64
#  12  oil_electricity          236 non-null    float64
# ...

# %%
#For Items like GDP  it doesnt make sense to replace the null values with a 0 ,so let's try FWD fill and then backwards fill
#looks like we have a lot of empty Values
nulls=energydata.isna().sum()
for i in nulls.index:
    if nulls[i]>0:
        energydata[i].ffill(inplace=True)
        energydata[i].bfill(inplace=True)
energydata.isna().sum()
# Out:
# country                    0
# year                       0
# coal_production            0
# electricity_generation     0
# energy_cons_change_pct     0
# energy_cons_change_twh     0
# biofuel_electricity        0
# coal_electricity           0
# fossil_electricity         0
# gas_electricity            0
# hydro_electricity          0
# nuclear_electricity        0
# oil_electricity            0
# renewables_electricity     0
# oil_production             0
# fossil_share_energy        0
# fossil_cons_change_twh     0
# fossil_fuel_consumption    0
# fossil_cons_change_pct     0
# population                 0
# gdp                        0
# gas_production             0
# solar_electricity          0
# wind_electricity           0
# energy_per_gdp             0
# energy_per_capita          0
# dtype: int64

# %%
energydata.tail(3)
# Out:
#              country  year  coal_production  electricity_generation  \
# 16367  United States  2018         4277.455                4203.937
# 16368  United States  2019         3972.480                4161.834
# 16369  United States  2020         3972.480                4049.847
#
#        energy_cons_change_pct  energy_cons_change_twh  biofuel_electricity  \
# 16367                   3.544                 908.999               61.901
# 16368                  -0.998                -265.032               57.507
# 16369                  -0.998                -265.032               56.055
#
#        coal_electricity  fossil_electricity  gas_electricity  ...  \
# 16367          1145.962            2666.350         1482.189  ...
# 16368           964.957            2595.032         1598.303  ...
# 16369           773.806            2431.990         1629.237  ...
#
#        fossil_cons_change_twh  fossil_fuel_consumption  \
# 16367                 864.750                22196.473
# ...

# %%
# data summary 
energydata.describe( include='all' , percentiles=[] , datetime_is_numeric=True)
# Out:
#        country         year  coal_production  electricity_generation  \
# count      246   246.000000       246.000000              246.000000
# unique       8          NaN              NaN                     NaN
# top     France          NaN              NaN                     NaN
# freq        31          NaN              NaN                     NaN
# mean       NaN  2004.878049      1511.214289              930.948492
# std        NaN     8.895388      1869.463810             1164.309796
# min        NaN  1990.000000         4.860000               41.952000
# 50%        NaN  2005.000000      1278.996500              548.631000
# max        NaN  2020.000000      6694.609000             4203.937000
#
#         energy_cons_change_pct  energy_cons_change_twh  biofuel_electricity  \
# count               246.000000              246.000000           246.000000
# unique                     NaN                     NaN                  NaN
# ...

# %%
correlation = energydata. corr ()  
correlation. style. background_gradient (cmap = 'BrBG')
# Out:
# <style type="text/css">
# #T_76d66_row0_col0, #T_76d66_row1_col1, #T_76d66_row2_col2, #T_76d66_row3_col3, #T_76d66_row4_col4, #T_76d66_row5_col5, #T_76d66_row6_col6, #T_76d66_row7_col7, #T_76d66_row8_col8, #T_76d66_row9_col9, #T_76d66_row10_col10, #T_76d66_row11_col11, #T_76d66_row12_col12, #T_76d66_row13_col13, #T_76d66_row14_col14, #T_76d66_row15_col15, #T_76d66_row16_col7, #T_76d66_row16_col16, #T_76d66_row17_col17, #T_76d66_row18_col18, #T_76d66_row19_col19, #T_76d66_row20_col20, #T_76d66_row21_col21, #T_76d66_row22_col22, #T_76d66_row23_col23, #T_76d66_row24_col24 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_76d66_row0_col1 {
#   background-color: #663a07;
#   color: #f1f1f1;
# }
# #T_76d66_row0_col2, #T_76d66_row0_col5, #T_76d66_row11_col5, #T_76d66_row15_col11 {
#   background-color: #c99546;
#   color: #f1f1f1;
# }
# #T_76d66_row0_col3 {
#   background-color: #7e4909;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# we have added some calculations to show the correlation between the variables
# so the first thing to notice is that most of the variables are strongly corelated between them taking for an example :
# 1- coal-productio in stronly and psitively corelated with the nuclear electricity
# 2- also when the coal prodution augmente the fossil

# %%
correlation = energydata.corr ()  
seaborn.heatmap (correlation)

# %%
fig = px.scatter(energydata, x="energy_per_capita", y="coal_production", color="country", size="population", hover_name="country", log_x=True, size_max=60)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# we are ploting above this text the relationship between the energy consumption per capital and thecoal production
# so we see for most countries the energy consumption grows when the coal production is getting higer, and the united states is considerd as the country with the highest production of the coal
# while Egypt and saudi arabia Japan and france are consuming more and more even if there is not an increase,ent on the coal production side

# %%
data = energydata

#combine coal_production,gas_production,oil_production into one column

data['fossil_production'] = data['coal_production'] + data['gas_production'] + data['oil_production']

#plot fossil_production vs energy_per_capita

fig = px.scatter(data, x="fossil_production", y="energy_per_capita", color="country", hover_name="country", size_max=60)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = energydata

#combine coal_eletricity,gas_electricity,oil_electricity into one column

data['fossil_electricity'] = data['coal_electricity'] + data['gas_electricity'] + data['oil_electricity']

#plot fossil_electricity vs fossil_production

fig = px.scatter(data, y="fossil_electricity", x="fossil_production", color="country", hover_name="country", size_max=60)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# we have combined the three variables that are considered as fossil_electricity, and ploted it's values depending on the Fossil_production on each country, we observe that
#
# *    only Japan is keeping consuming electricity even when the production is not progressing so that might cause problems in the future,
# *    but the other countries are developping their wqys to producte the fossil and consume it logicaly in time,
# *   except GERMANY and UK they keep producting the fossil even they consume just a little amount of it.

# %%
#looks like we have a lot of empty Values
nulls=energydata.isna().sum()
nulls
# Out:
# country                    0
# year                       0
# coal_production            0
# electricity_generation     0
# energy_cons_change_pct     0
# energy_cons_change_twh     0
# biofuel_electricity        0
# coal_electricity           0
# fossil_electricity         0
# gas_electricity            0
# hydro_electricity          0
# nuclear_electricity        0
# oil_electricity            0
# renewables_electricity     0
# oil_production             0
# fossil_share_energy        0
# fossil_cons_change_twh     0
# fossil_fuel_consumption    0
# fossil_cons_change_pct     0
# population                 0
# gdp                        0
# gas_production             0
# solar_electricity          0
# wind_electricity           0
# energy_per_gdp             0
# energy_per_capita          0
# fossil_production          0
# dtype: int64

# %% [markdown]
# #Crow Search Algorithm aplication

# %%
energy_cols = ["energy_cons_change_pct", "energy_cons_change_twh", "energy_per_capita", "fossil_cons_change_pct", "fossil_share_energy", "fossil_cons_change_twh", "fossil_fuel_consumption"]
energydata = energydata[energy_cols]

# Define the objective function to minimize energy consumption
def objective_function(row):
    energy_consumption = row["energy_cons_change_twh"] 
    + row["fossil_cons_change_twh"] + row["fossil_fuel_consumption"] 
    +row["energy_cons_change_pct"] + row["energy_per_capita"] 
    +row['fossil_share_energy'] + row['fossil_cons_change_pct']
    return energy_consumption

# Define the parameters of the crow search algorithm
num_crows = 50  # number of crows in the population
num_iterations = 100  # number of iterations to run the algorithm

# Initialize the population of crows with random solutions
crows = []
for i in range(num_crows):
    crow = {}
    crow["solution"] = np.random.randint(low=0, high=len(energydata), size=1)[0]  # random index in the dataset
    crow["fitness"] = objective_function(energydata.iloc[crow["solution"]])  # evaluate the fitness of the solution
    crows.append(crow)

# Run the crow search algorithm for the specified number of iterations
for i in range(num_iterations):
    # Sort the crows by fitness
    crows = sorted(crows, key=lambda x: x["fitness"])

    # Select the best crow (i.e. the one with the lowest energy consumption)
    best_crow = crows[0]

    # Generate new solutions for the rest of the crows using the best crow as a reference
    for j in range(1, num_crows):
        crow = crows[j]
        new_solution = best_crow["solution"] + np.random.normal(loc=0, scale=1)
        new_solution = int(np.clip(new_solution, 0, len(energydata)-1))  # clip the solution to the range [0, len(df)-1]
        crow["solution"] = new_solution
        crow["fitness"] = objective_function(energydata.iloc[new_solution])

# Sort the crows by fitness again
crows = sorted(crows, key=lambda x: x["fitness"])

# The best solution is the one with the lowest energy consumption
best_solution = crows[0]["solution"]

# Print the minimum energy consumption found by the crow search algorithm
print(f"Minimum energy consumption: {crows[0]['fitness']}")


# Print the row in the dataset corresponding to the minimum energy consumption
print(energydata.iloc[best_solution])
# Out:
# Minimum energy consumption: 5108.017000000001
# energy_cons_change_pct        7.321
# energy_cons_change_twh      156.061
# energy_per_capita          2619.875
# fossil_cons_change_pct        7.244
# fossil_share_energy          91.154
# fossil_cons_change_twh      140.871
# fossil_fuel_consumption    2085.491
# Name: 7297, dtype: float64
